# %%
import cv2

# Read an RGB image
image = cv2.imread('../../images/peppers.png')

# Check if the image was successfully loaded
if image is not None:
    # Display the original image
    cv2.imshow('RGB Image', image)
    
    image_hsv=cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    image_lab=cv2.cvtColor(image,cv2.COLOR_RGB2Lab)
    image_bgr=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    cv2.imshow('HSV image',image_rgb)
    cv2.imshow('Lab image',image_bgr)
    cv2.imshow('BGR image',image_lab)
    cv2.waitKey(1000) # wait 2000 ms 
    cv2.destroyWindow('RGB Image')
    cv2.destroyWindow('BGR Image')
    cv2.destroyWindow('HSV Image')
    cv2.destroyWindow('Lab Image')
    cv2.imshow('H channel image',image_hsv[:,:,1])
    cv2.imshow('L channel image',image_lab[:,:,1])
    cv2.waitKey(1000)
    #cv2.destroyAllWindows()
    cv2.waitKey(1)
else:
    print('Error: Unable to load image')
